# %%
import os
import numpy as np
import cv2
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# ----------------------------------------load data module begin-----------------------------------------------------
def load_path(data_set, root_dir = 'B:/MURA/MURA-v1.1/', data_type = 'XR_ELBOW'):
    # load MURA data and return data path list and label numpy array
    data_path = root_dir + data_set + '/' + data_type + '/'
    Path = []
    labels = []
    for root, dirs, files in os.walk(data_path):  # read all images, os.walk returns iterators genertor traverses all files
        for name in files:
            if root.split('_')[-1] == 'positive':  # positive label == 1；
                path_1 = os.path.join(root, name)
                Path.append(path_1)
                labels += [1]
            elif root.split('_')[-1] == 'negative':  # negative label == 1；
                path_1 = os.path.join(root, name)
                Path.append(path_1)
                labels += [0]
            else:
                continue
    labels = np.asarray(labels)
    return Path, labels

#  path list in, image list out
def load_image(Path='../valid', imsize=224):
    Images = []
    i = 1
    for path in Path:

        image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

        if image is None:
            print("null")
            continue
        else:
            if i % 500 == 0:
                print ("loading image ", i)
            
            image = cv2.resize(image, (imsize, imsize))   # resize images
            image = randome_rotation_flip(image, imsize)  # predeal images
            Images.append(image)
            i = i+1

    Images = np.asarray(Images).astype('float32')

    # normalization
    print("Starting normalization.......")
    mean = np.mean(Images[:, :, :])
    std = np.std(Images[:, :, :])
    Images[:, :, :] = (Images[:, :, :] - mean) / std
    print("normalization finished")

    Images = np.expand_dims(Images, axis=1)

    return Images

# inner function used by load_image
def randome_rotation_flip(image, imsize=224):
    if random.randint(0, 1):
        image = cv2.flip(image, 1)

    if random.randint(0, 1):
        angle = random.randint(-30, 30)
        M = cv2.getRotationMatrix2D((imsize / 2, imsize / 2), angle, 1)
        # third parameter: the transformed image size
        image = cv2.warpAffine(image, M, (imsize, imsize))
    return image

# ----------------------------------------load data module end-----------------------------------------------------

# %%
# -----------------------------------network hyperparameter begin--------------------------------
im_size = 224  # input image size
batch_size = 50 
epochs = 30
x_shape  = (batch_size, 1, 224, 224)
model_save = True
model_reload = False
drop_out_rate = 0.2
my_init = keras.initializers.RandomNormal(mean=0.0, stddev=1.0, seed=None)

# -----------------------------------network hyperparameter end--------------------------------

# %%
# ----------------------------------------net build module begin-----------------------------------------------------

if model_reload:
    deep_model = keras.models.load_model('MURA_keras_7_21.h5')
else:
    deep_model = keras.Sequential(
    [
    layers.BatchNormalization(input_shape=((x_shape[1], x_shape[2], x_shape[3])),axis=1),
    
    #CNN1
    layers.Conv2D(filters=16, kernel_size=(3,3), strides=(1,1),padding='same', 
                  kernel_initializer=my_init, 
                  activation='selu', data_format='channels_first'),
    layers.Conv2D(filters=16, kernel_size=(3,3), strides=(1,1),padding='same', 
                  kernel_initializer=my_init, 
                  activation='selu', data_format='channels_first'),
    layers.MaxPool2D(pool_size=(2,2), data_format='channels_first'),
    
    layers.BatchNormalization(axis=1),
    
    #CNN2
    layers.Conv2D(filters=32, kernel_size=(3,3), strides=(1,1), padding='same', 
                      kernel_initializer=my_init, 
                      activation='selu', data_format='channels_first'),
    layers.Conv2D(filters=32, kernel_size=(3,3), strides=(1,1),padding='same', 
                      kernel_initializer=my_init, 
                      activation='selu', data_format='channels_first'),
    layers.MaxPool2D(pool_size=(2,2), data_format='channels_first'),
    
    layers.BatchNormalization(axis=1),
    
    #CNN3
    layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), padding='same', 
                      kernel_initializer=my_init, 
                      activation='selu', data_format='channels_first'),
    layers.Conv2D(filters=64, kernel_size=(3,3), strides=(1,1),padding='same', 
                      kernel_initializer=my_init, 
                      activation='selu', data_format='channels_first'),
    layers.MaxPool2D(pool_size=(2,2), data_format='channels_first'),
    
    layers.BatchNormalization(axis=1),
    
    #CNN4
    layers.Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', 
                      kernel_initializer=my_init, 
                      activation='selu', data_format='channels_first'),
    layers.MaxPool2D(pool_size=(2,2), data_format='channels_first'),
    layers.Dropout(drop_out_rate),
    
    layers.BatchNormalization(axis=1),
    
    #CNN5
    layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1),padding='same', 
                      kernel_initializer=my_init, 
                      activation='selu', data_format='channels_first'),
    layers.MaxPool2D(pool_size=(14,14), data_format='channels_first'),
    
    #FC6
    layers.Flatten(),
    layers.BatchNormalization(),
    layers.Dropout(drop_out_rate),
    layers.Dense(32, activation='selu', kernel_initializer=my_init),
        
    #FC8
    layers.BatchNormalization(),
    layers.Dropout(drop_out_rate),
    layers.Dense(16, activation='selu', kernel_initializer=my_init),
        
    #FC9
    layers.BatchNormalization(),
    layers.Dropout(drop_out_rate),
    layers.Dense(1, activation='sigmoid', kernel_initializer=my_init),
     ])
    
    deep_model.compile(optimizer=keras.optimizers.Adam(),
                 loss='binary_crossentropy',
                metrics=['accuracy'])
    deep_model.summary()
        
# ----------------------------------------net build module begin-----------------------------------------------------
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_v2 (Batc (None, 1, 224, 224)       4
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 224, 224)      160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 224, 224)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 112, 112)      0
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 16, 112, 112)      64
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 112, 112)      4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 112, 112)      9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 56, 56)        0
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 32, 56, 56)        128
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 56, 56)        18496
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 56, 56)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 64, 28, 28)        0
# _________________________________________________________________
# batch_normalization_v2_3 (Ba (None, 64, 28, 28)        256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 28, 28)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128, 14, 14)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 14, 14)       0
# _________________________________________________________________
# batch_normalization_v2_4 (Ba (None, 128, 14, 14)       512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 256, 14, 14)       33024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 256, 1, 1)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# batch_normalization_v2_5 (Ba (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                8224
# _________________________________________________________________
# batch_normalization_v2_6 (Ba (None, 32)                128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_v2_7 (Ba (None, 16)                64
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 189,621
# Trainable params: 188,531
# Non-trainable params: 1,090
# _________________________________________________________________

# %%
# -------------------------------load train data module begin-----------------------------

# 训练数据
im_size = 224
x_train_path, y_train = load_path(data_set='train')
x_train = load_image(x_train_path, imsize=im_size)
print(x_train.shape)
print(y_train.shape)
  
# -------------------------------load train data module end-----------------------------
# Out:
# loading image  500
# loading image  1000
# loading image  1500
# loading image  2000
# loading image  2500
# loading image  3000
# loading image  3500
# loading image  4000
# loading image  4500
# Starting normalization.......
# normalization finished
# (4931, 1, 224, 224)
# (4931,)

# %%
# 开始训练
history = deep_model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Train on 4437 samples, validate on 494 samples
# Epoch 1/30
# 4437/4437 [==============================] - 46s 10ms/sample - loss: 2.1635 - accuracy: 0.5130 - val_loss: 0.5648 - val_accuracy: 0.8401
# Epoch 2/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 1.7631 - accuracy: 0.5260 - val_loss: 0.9073 - val_accuracy: 0.6275
# Epoch 3/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 1.3676 - accuracy: 0.5368 - val_loss: 0.9335 - val_accuracy: 0.5182
# Epoch 4/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 1.2074 - accuracy: 0.5303 - val_loss: 0.6588 - val_accuracy: 0.5972
# Epoch 5/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 1.1004 - accuracy: 0.5472 - val_loss: 0.6414 - val_accuracy: 0.6012
# Epoch 6/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 1.0591 - accuracy: 0.5238 - val_loss: 0.5457 - val_accuracy: 0.6964
# Epoch 7/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.9639 - accuracy: 0.5468 - val_loss: 0.5697 - val_accuracy: 0.6619
# Epoch 8/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.9107 - accuracy: 0.5504 - val_loss: 0.5651 - val_accuracy: 0.6700
# Epoch 9/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.8891 - accuracy: 0.5486 - val_loss: 0.5119 - val_accuracy: 0.7874
# Epoch 10/30
# 4437/4437 [==============================] - 38s 9ms/sample - loss: 0.8551 - accuracy: 0.5574 - val_loss: 0.5287 - val_accuracy: 0.7753
# Epoch 11/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.8414 - accuracy: 0.5486 - val_loss: 0.5542 - val_accuracy: 0.7328
# Epoch 12/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.7959 - accuracy: 0.5499 - val_loss: 0.5760 - val_accuracy: 0.7186
# Epoch 13/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.7880 - accuracy: 0.5641 - val_loss: 0.5535 - val_accuracy: 0.7551
# Epoch 14/30
# 4437/4437 [==============================] - 38s 9ms/sample - loss: 0.7709 - accuracy: 0.5585 - val_loss: 0.5998 - val_accuracy: 0.6660
# Epoch 15/30
# 4437/4437 [==============================] - 38s 9ms/sample - loss: 0.7467 - accuracy: 0.5650 - val_loss: 0.6235 - val_accuracy: 0.6032
# Epoch 16/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.7388 - accuracy: 0.5571 - val_loss: 0.5836 - val_accuracy: 0.7024
# Epoch 17/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.7214 - accuracy: 0.5610 - val_loss: 0.5848 - val_accuracy: 0.7045
# Epoch 18/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.7183 - accuracy: 0.5652 - val_loss: 0.5869 - val_accuracy: 0.6964
# Epoch 19/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.7069 - accuracy: 0.5812 - val_loss: 0.5992 - val_accuracy: 0.6700
# Epoch 20/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.7082 - accuracy: 0.5716 - val_loss: 0.5867 - val_accuracy: 0.7186
# Epoch 21/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6934 - accuracy: 0.5808 - val_loss: 0.6295 - val_accuracy: 0.5951
# Epoch 22/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6948 - accuracy: 0.5918 - val_loss: 0.5872 - val_accuracy: 0.7146
# Epoch 23/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6857 - accuracy: 0.5871 - val_loss: 0.5944 - val_accuracy: 0.6842
# Epoch 24/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6813 - accuracy: 0.5788 - val_loss: 0.5908 - val_accuracy: 0.6822
# Epoch 25/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6705 - accuracy: 0.6049 - val_loss: 0.5605 - val_accuracy: 0.7834
# Epoch 26/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6700 - accuracy: 0.6002 - val_loss: 0.5933 - val_accuracy: 0.6802
# Epoch 27/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6629 - accuracy: 0.6040 - val_loss: 0.5548 - val_accuracy: 0.7591
# Epoch 28/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6584 - accuracy: 0.6114 - val_loss: 0.5879 - val_accuracy: 0.6802
# Epoch 29/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6517 - accuracy: 0.6162 - val_loss: 0.6186 - val_accuracy: 0.5972
# Epoch 30/30
# 4437/4437 [==============================] - 39s 9ms/sample - loss: 0.6583 - accuracy: 0.6236 - val_loss: 0.5698 - val_accuracy: 0.7045

# %%
# test
x_test_path, y_test = load_path(data_set='valid')
x_test = load_image(x_test_path, im_size)
res = deep_model.evaluate(x_test, y_test)
# Out:
# Starting normalization.......
# normalization finished
# 465/465 [==============================] - 1s 3ms/sample - loss: 0.6368 - accuracy: 0.6688

# %%
if model_save:
    deep_model.save('MURA_keras_7_21_3FC.h5')
