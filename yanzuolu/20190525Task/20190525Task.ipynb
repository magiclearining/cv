# %%
from Mura import *

# %%
acc = {}
kappa = {}

# %%
for study_type in ['XR_SHOULDER','XR_FINGER','XR_FOREARM','XR_HAND','XR_HUMERUS','XR_ELBOW','XR_WRIST']:

    print(study_type, ": \n")
    study_data = get_study_level_data(study_type)
    dataloaders = get_dataloaders(study_data, batch_size=16)
    dataset_sizes = {x: len(study_data[x]) for x in data_cat}

    model = models.densenet121(pretrained=True)
    model.classifier = nn.Linear(in_features=1024, out_features=2, bias=False)
    model = model.cuda()

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=1,verbose=True)

    model, acc[study_type], kappa[study_type] = train_model(model, criterion, optimizer, dataloaders, scheduler, dataset_sizes, num_epochs=10)
    print('-' * 10)
    print()
    torch.cuda.empty_cache()
# Out:
#   0%|          | 96/36804 [00:00<00:38, 958.47it/s]
# XR_SHOULDER :
# 100%|██████████| 36804/36804 [00:11<00:00, 3222.72it/s]
# 100%|██████████| 3197/3197 [00:00<00:00, 5339.10it/s]
# Train batches: 524
# Valid batches: 36
#
# Epoch 1/10
# ----------
#
# train Loss: 0.0357 Acc: 0.7096
# Confusion Meter:
#  [[3079 1132]
#  [1301 2867]]
# kappa:  0.419126894691074
#
#
# valid Loss: 0.0335 Acc: 0.7655
# Confusion Meter:
#  [[246  39]
#  [ 93 185]]
# kappa:  0.5298895509925229
#
# Time elapsed: 2m 2s
#
# Epoch 2/10
# ----------
#
# train Loss: 0.0312 Acc: 0.7667
# Confusion Meter:
#  [[3358  853]
#  [1102 3066]]
# kappa:  0.53320253119576
#
#
# valid Loss: 0.0320 Acc: 0.7638
# Confusion Meter:
#  [[219  66]
#  [ 67 211]]
# kappa:  0.5274371580216214
#
# Time elapsed: 4m 5s
#
# Epoch 3/10
# ----------
#
# train Loss: 0.0297 Acc: 0.7815
# Confusion Meter:
#  [[3384  827]
#  [1004 3164]]
# kappa:  0.5628487131533482
#
#
# valid Loss: 0.0336 Acc: 0.7691
# Confusion Meter:
#  [[257  28]
#  [102 176]]
# kappa:  0.536602043788226
#
# Time elapsed: 6m 7s
#
# Epoch 4/10
# ----------
#
# train Loss: 0.0277 Acc: 0.8018
# Confusion Meter:
#  [[3473  738]
#  [ 923 3245]]
# kappa:  0.6034323294630984
#
#
# valid Loss: 0.0330 Acc: 0.7780
# Confusion Meter:
#  [[255  30]
#  [ 95 183]]
# kappa:  0.5546027024461252
#
# Epoch     3: reducing learning rate of group 0 to 1.0000e-05.
# Time elapsed: 8m 9s
#
# Epoch 5/10
# ----------
#
# train Loss: 0.0236 Acc: 0.8369
# Confusion Meter:
#  [[3611  600]
#  [ 767 3401]]
# kappa:  0.6736327212595613
#
#
# valid Loss: 0.0315 Acc: 0.8028
# Confusion Meter:
#  [[220  65]
#  [ 46 232]]
# kappa:  0.6059536045096569
#
# Time elapsed: 10m 12s
#
# Epoch 6/10
# ----------
#
# train Loss: 0.0217 Acc: 0.8512
# Confusion Meter:
#  [[3681  530]
#  [ 717 3451]]
# kappa:  0.7022750770732633
#
#
# valid Loss: 0.0313 Acc: 0.7975
# Confusion Meter:
#  [[246  39]
#  [ 75 203]]
# kappa:  0.5943188713592235
#
# Time elapsed: 12m 14s
#
# Epoch 7/10
# ----------
#
# train Loss: 0.0205 Acc: 0.8595
# Confusion Meter:
#  [[3682  529]
#  [ 648 3520]]
# kappa:  0.7190111944120453
#
#
# valid Loss: 0.0324 Acc: 0.8011
# Confusion Meter:
#  [[233  52]
#  [ 60 218]]
# kappa:  0.6019292442110047
#
# Time elapsed: 14m 17s
#
# Epoch 8/10
# ----------
#
# train Loss: 0.0197 Acc: 0.8631
# Confusion Meter:
#  [[3732  479]
#  [ 668 3500]]
# kappa:  0.7261497005436908
#
#
# valid Loss: 0.0314 Acc: 0.8028
# Confusion Meter:
#  [[236  49]
#  [ 62 216]]
# kappa:  0.6053962581060689
#
# Epoch     7: reducing learning rate of group 0 to 1.0000e-06.
# Time elapsed: 16m 19s
#
# Epoch 9/10
# ----------
#
# train Loss: 0.0184 Acc: 0.8792
# Confusion Meter:
#  [[3742  469]
#  [ 543 3625]]
# kappa:  0.7584154674308742
#
#
# valid Loss: 0.0321 Acc: 0.8064
# Confusion Meter:
#  [[237  48]
#  [ 61 217]]
# kappa:  0.6125062354374909
#
# Time elapsed: 18m 21s
#
# Epoch 10/10
# ----------
#
# train Loss: 0.0179 Acc: 0.8830
# Confusion Meter:
#  [[3768  443]
#  [ 537 3631]]
# kappa:  0.7660487718487903
#
#
# valid Loss: 0.0318 Acc: 0.8064
# Confusion Meter:
#  [[235  50]
#  [ 59 219]]
# kappa:  0.6125747331073189
#
# Epoch     9: reducing learning rate of group 0 to 1.0000e-07.
# Time elapsed: 20m 24s
#
# Training complete in 20m 24s
# Best valid Acc: 0.806394
# Best valid kappa: 0.612506
#  26%|██▋       | 9744/36804 [00:00<00:00, 96956.50it/s]
# ----------
#
# XR_FINGER :
# 100%|██████████| 36804/36804 [00:06<00:00, 5922.88it/s]
# 100%|██████████| 3197/3197 [00:00<00:00, 6637.25it/s]
# Train batches: 320
# Valid batches: 29
#
# Epoch 1/10
# ----------
# train Loss: 0.0335 Acc: 0.7299
# Confusion Meter:
#  [[2601  537]
#  [ 842 1126]]
# kappa:  0.41295753539300856
#
#
# valid Loss: 0.0371 Acc: 0.7267
# Confusion Meter:
#  [[197  17]
#  [109 138]]
# kappa:  0.46588568486096804
#
# Time elapsed: 1m 15s
#
# Epoch 2/10
# ----------
#
# train Loss: 0.0285 Acc: 0.7869
# Confusion Meter:
#  [[2717  421]
#  [ 667 1301]]
# kappa:  0.5394870478742717
#
#
# valid Loss: 0.0427 Acc: 0.6790
# Confusion Meter:
#  [[212   2]
#  [146 101]]
# kappa:  0.38237317594235437
#
# Time elapsed: 2m 31s
#
# Epoch 3/10
# ----------
#
# train Loss: 0.0256 Acc: 0.8239
# Confusion Meter:
#  [[2799  339]
#  [ 560 1408]]
# kappa:  0.6204046475372785
#
#
# valid Loss: 0.0347 Acc: 0.7679
# Confusion Meter:
#  [[164  50]
#  [ 57 190]]
# kappa:  0.5344181524724626
#
# Time elapsed: 3m 46s
#
# Epoch 4/10
# ----------
#
# train Loss: 0.0236 Acc: 0.8378
# Confusion Meter:
#  [[2851  287]
#  [ 541 1427]]
# kappa:  0.6492639614374927
#
#
# valid Loss: 0.0338 Acc: 0.7766
# Confusion Meter:
#  [[183  31]
#  [ 72 175]]
# kappa:  0.5565196275299105
#
# Time elapsed: 5m 1s
#
# Epoch 5/10
# ----------
#
# train Loss: 0.0223 Acc: 0.8488
# Confusion Meter:
#  [[2826  312]
#  [ 460 1508]]
# kappa:  0.6763155353486382
#
#
# valid Loss: 0.0402 Acc: 0.7267
# Confusion Meter:
#  [[196  18]
#  [108 139]]
# kappa:  0.46556134184715603
#
# Time elapsed: 6m 16s
#
# Epoch 6/10
# ----------
#
# train Loss: 0.0208 Acc: 0.8549
# Confusion Meter:
#  [[2832  306]
#  [ 435 1533]]
# kappa:  0.68987932858359
#
#
# valid Loss: 0.0393 Acc: 0.7527
# Confusion Meter:
#  [[188  26]
#  [ 88 159]]
# kappa:  0.5123141738275087
#
# Epoch     5: reducing learning rate of group 0 to 1.0000e-05.
# Time elapsed: 7m 32s
#
# Epoch 7/10
# ----------
#
# train Loss: 0.0161 Acc: 0.8954
# Confusion Meter:
#  [[2944  194]
#  [ 340 1628]]
# kappa:  0.7761472824914362
#
#
# valid Loss: 0.0371 Acc: 0.7722
# Confusion Meter:
#  [[185  29]
#  [ 76 171]]
# kappa:  0.5487428566101411
#
# Time elapsed: 8m 47s
#
# Epoch 8/10
# ----------
#
# train Loss: 0.0138 Acc: 0.9119
# Confusion Meter:
#  [[2974  164]
#  [ 286 1682]]
# kappa:  0.8117939508673844
#
#
# valid Loss: 0.0418 Acc: 0.7766
# Confusion Meter:
#  [[192  22]
#  [ 81 166]]
# kappa:  0.5589664044286338
#
# Epoch     7: reducing learning rate of group 0 to 1.0000e-06.
# Time elapsed: 10m 3s
#
# Epoch 9/10
# ----------
#
# train Loss: 0.0128 Acc: 0.9207
# Confusion Meter:
#  [[2977  161]
#  [ 244 1724]]
# kappa:  0.8312452903356587
#
#
# valid Loss: 0.0389 Acc: 0.7679
# Confusion Meter:
#  [[181  33]
#  [ 74 173]]
# kappa:  0.5392970887932081
#
# Time elapsed: 11m 18s
#
# Epoch 10/10
# ----------
#
# train Loss: 0.0123 Acc: 0.9244
# Confusion Meter:
#  [[2989  149]
#  [ 237 1731]]
# kappa:  0.8390853584459049
#
#
# valid Loss: 0.0405 Acc: 0.7701
# Confusion Meter:
#  [[186  28]
#  [ 78 169]]
# kappa:  0.5448652273531658
#
# Epoch     9: reducing learning rate of group 0 to 1.0000e-07.
# Time elapsed: 12m 33s
#
# Training complete in 12m 33s
# Best valid Acc: 0.776573
# Best valid kappa: 0.556520
#  80%|████████  | 29521/36804 [00:00<00:00, 294761.21it/s]
# ----------
#
# XR_FOREARM :
# 100%|██████████| 36804/36804 [00:02<00:00, 17992.08it/s]
# 100%|██████████| 3197/3197 [00:00<00:00, 10041.37it/s]
# Train batches: 115
# Valid batches: 19
#
# Epoch 1/10
# ----------
# train Loss: 0.0335 Acc: 0.7600
# Confusion Meter:
#  [[1025  139]
#  [ 299  362]]
# kappa:  0.45187228113291383
#
#
# valid Loss: 0.0377 Acc: 0.7209
# Confusion Meter:
#  [[145   5]
#  [ 79  72]]
# kappa:  0.44276457883369313
#
# Time elapsed: 0m 28s
#
# Epoch 2/10
# ----------
#
# train Loss: 0.0255 Acc: 0.8345
# Confusion Meter:
#  [[1064  100]
#  [ 202  459]]
# kappa:  0.629479489775476
#
#
# valid Loss: 0.0370 Acc: 0.7508
# Confusion Meter:
#  [[146   4]
#  [ 71  80]]
# kappa:  0.5023916062336059
#
# Time elapsed: 0m 56s
#
# Epoch 3/10
# ----------
#
# train Loss: 0.0223 Acc: 0.8586
# Confusion Meter:
#  [[1091   73]
#  [ 185  476]]
# kappa:  0.6823886049787113
#
#
# valid Loss: 0.0293 Acc: 0.8140
# Confusion Meter:
#  [[147   3]
#  [ 53  98]]
# kappa:  0.6283131201764058
#
# Time elapsed: 1m 24s
#
# Epoch 4/10
# ----------
#
# train Loss: 0.0192 Acc: 0.8811
# Confusion Meter:
#  [[1099   65]
#  [ 152  509]]
# kappa:  0.7351086621357055
#
#
# valid Loss: 0.0385 Acc: 0.7841
# Confusion Meter:
#  [[146   4]
#  [ 61  90]]
# kappa:  0.5686443106907425
#
# Time elapsed: 1m 52s
#
# Epoch 5/10
# ----------
#
# train Loss: 0.0182 Acc: 0.8855
# Confusion Meter:
#  [[1091   73]
#  [ 136  525]]
# kappa:  0.7469177948124865
#
#
# valid Loss: 0.0301 Acc: 0.8073
# Confusion Meter:
#  [[141   9]
#  [ 49 102]]
# kappa:  0.6149536832818703
#
# Epoch     4: reducing learning rate of group 0 to 1.0000e-05.
# Time elapsed: 2m 19s
#
# Epoch 6/10
# ----------
#
# train Loss: 0.0139 Acc: 0.9178
# Confusion Meter:
#  [[1126   38]
#  [ 112  549]]
# kappa:  0.8176927595222652
#
#
# valid Loss: 0.0308 Acc: 0.8106
# Confusion Meter:
#  [[140  10]
#  [ 47 104]]
# kappa:  0.6215673732271654
#
# Time elapsed: 2m 47s
#
# Epoch 7/10
# ----------
#
# train Loss: 0.0122 Acc: 0.9255
# Confusion Meter:
#  [[1123   41]
#  [  95  566]]
# kappa:  0.8358081190966669
#
#
# valid Loss: 0.0325 Acc: 0.8173
# Confusion Meter:
#  [[144   6]
#  [ 49 102]]
# kappa:  0.6348940299494962
#
# Epoch     6: reducing learning rate of group 0 to 1.0000e-06.
# Time elapsed: 3m 15s
#
# Epoch 8/10
# ----------
#
# train Loss: 0.0116 Acc: 0.9375
# Confusion Meter:
#  [[1128   36]
#  [  78  583]]
# kappa:  0.8629159468188988
#
#
# valid Loss: 0.0333 Acc: 0.8040
# Confusion Meter:
#  [[144   6]
#  [ 53  98]]
# kappa:  0.6083754162348116
#
# Time elapsed: 3m 43s
#
# Epoch 9/10
# ----------
#
# train Loss: 0.0110 Acc: 0.9468
# Confusion Meter:
#  [[1139   25]
#  [  72  589]]
# kappa:  0.8831646940568267
#
#
# valid Loss: 0.0322 Acc: 0.8040
# Confusion Meter:
#  [[143   7]
#  [ 52  99]]
# kappa:  0.6083581431249312
#
# Epoch     8: reducing learning rate of group 0 to 1.0000e-07.
# Time elapsed: 4m 11s
#
# Epoch 10/10
# ----------
#
# train Loss: 0.0116 Acc: 0.9326
# Confusion Meter:
#  [[1129   35]
#  [  88  573]]
# kappa:  0.8515523271846888
#
#
# valid Loss: 0.0290 Acc: 0.8206
# Confusion Meter:
#  [[140  10]
#  [ 44 107]]
# kappa:  0.641461154983015
#
# Time elapsed: 4m 39s
#
# Training complete in 4m 39s
# Best valid Acc: 0.820598
# Best valid kappa: 0.641461
#  85%|████████▌ | 31345/36804 [00:00<00:00, 310313.35it/s]
# ----------
#
# XR_HAND :
# 100%|██████████| 36804/36804 [00:06<00:00, 5294.98it/s]
# 100%|██████████| 3197/3197 [00:00<00:00, 6507.60it/s]
# Train batches: 347
# Valid batches: 29
#
# Epoch 1/10
# ----------
#
# train Loss: 0.0333 Acc: 0.7568
# Confusion Meter:
#  [[3822  237]
#  [1111  373]]
# kappa:  0.23728712174740513
#
#
# valid Loss: 0.0374 Acc: 0.6957
# Confusion Meter:
#  [[223  48]
#  [ 92  97]]
# kappa:  0.3483759991905291
#
# Time elapsed: 1m 21s
#
# Epoch 2/10
# ----------
#
# train Loss: 0.0294 Acc: 0.7972
# Confusion Meter:
#  [[3812  247]
#  [ 877  607]]
# kappa:  0.4023583237840461
#
#
# valid Loss: 0.0383 Acc: 0.7457
# Confusion Meter:
#  [[254  17]
#  [100  89]]
# kappa:  0.4372176677262842
#
# Time elapsed: 2m 43s
#
# Epoch 3/10
# ----------
#
# train Loss: 0.0273 Acc: 0.8171
# Confusion Meter:
#  [[3814  245]
#  [ 769  715]]
# kappa:  0.4746026570666975
#
#
# valid Loss: 0.0363 Acc: 0.7457
# Confusion Meter:
#  [[251  20]
#  [ 97  92]]
# kappa:  0.4400982064832924
#
# Time elapsed: 4m 5s
#
# Epoch 4/10
# ----------
#
# train Loss: 0.0257 Acc: 0.8320
# Confusion Meter:
#  [[3841  218]
#  [ 713  771]]
# kappa:  0.5209524968561113
#
#
# valid Loss: 0.0340 Acc: 0.7522
# Confusion Meter:
#  [[249  22]
#  [ 92  97]]
# kappa:  0.457693023640613
#
# Time elapsed: 5m 26s
#
# Epoch 5/10
# ----------
#
# train Loss: 0.0241 Acc: 0.8380
# Confusion Meter:
#  [[3824  235]
#  [ 663  821]]
# kappa:  0.5452162135591995
#
#
# valid Loss: 0.0308 Acc: 0.7848
# Confusion Meter:
#  [[250  21]
#  [ 78 111]]
# kappa:  0.5341843623419664
#
# Time elapsed: 6m 48s
#
# Epoch 6/10
# ----------
#
# train Loss: 0.0226 Acc: 0.8488
# Confusion Meter:
#  [[3826  233]
#  [ 605  879]]
# kappa:  0.5811213637181796
#
#
# valid Loss: 0.0380 Acc: 0.7543
# Confusion Meter:
#  [[248  23]
#  [ 90  99]]
# kappa:  0.46381416075259935
#
# Time elapsed: 8m 10s
#
# Epoch 7/10
# ----------
#
# train Loss: 0.0214 Acc: 0.8575
# Confusion Meter:
#  [[3825  234]
#  [ 556  928]]
# kappa:  0.6096465650356098
#
#
# valid Loss: 0.0329 Acc: 0.7957
# Confusion Meter:
#  [[225  46]
#  [ 48 141]]
# kappa:  0.5772141502239082
#
# Epoch     6: reducing learning rate of group 0 to 1.0000e-05.
# Time elapsed: 9m 31s
#
# Epoch 8/10
# ----------
#
# train Loss: 0.0172 Acc: 0.8914
# Confusion Meter:
#  [[3883  176]
#  [ 426 1058]]
# kappa:  0.7073769998707398
#
#
# valid Loss: 0.0327 Acc: 0.7978
# Confusion Meter:
#  [[239  32]
#  [ 61 128]]
# kappa:  0.5724565260843493
#
# Time elapsed: 10m 53s
#
# Epoch 9/10
# ----------
#
# train Loss: 0.0145 Acc: 0.9120
# Confusion Meter:
#  [[3920  139]
#  [ 349 1135]]
# kappa:  0.7649140536339809
#
#
# valid Loss: 0.0340 Acc: 0.7913
# Confusion Meter:
#  [[241  30]
#  [ 66 123]]
# kappa:  0.5561184488269706
#
# Epoch     8: reducing learning rate of group 0 to 1.0000e-06.
# Time elapsed: 12m 15s
#
# Epoch 10/10
# ----------
#
# train Loss: 0.0135 Acc: 0.9161
# Confusion Meter:
#  [[3932  127]
#  [ 338 1146]]
# kappa:  0.7759437826865188
#
#
# valid Loss: 0.0345 Acc: 0.7891
# Confusion Meter:
#  [[241  30]
#  [ 67 122]]
# kappa:  0.5511247032312583
#
# Time elapsed: 13m 37s
#
# Training complete in 13m 37s
# Best valid Acc: 0.797826
# Best valid kappa: 0.572457
#  23%|██▎       | 8473/36804 [00:00<00:00, 83318.69it/s]
# ----------
#
# XR_HUMERUS :
# 100%|██████████| 36804/36804 [00:01<00:00, 26369.33it/s]
# 100%|██████████| 3197/3197 [00:00<00:00, 10418.92it/s]
# Train batches: 80
# Valid batches: 18
#
# Epoch 1/10
# ----------
#
# train Loss: 0.0330 Acc: 0.7398
# Confusion Meter:
#  [[538 135]
#  [196 403]]
# kappa:  0.474852196472672
#
#
# valid Loss: 0.0238 Acc: 0.8542
# Confusion Meter:
#  [[129  19]
#  [ 23 117]]
# kappa:  0.7078825347758887
#
# Time elapsed: 0m 20s
#
# Epoch 2/10
# ----------
#
# train Loss: 0.0252 Acc: 0.8192
# Confusion Meter:
#  [[561 112]
#  [118 481]]
# kappa:  0.6369367468758144
#
#
# valid Loss: 0.0251 Acc: 0.8299
# Confusion Meter:
#  [[119  29]
#  [ 20 120]]
# kappa:  0.6600501059934478
#
# Time elapsed: 0m 40s
#
# Epoch 3/10
# ----------
#
# train Loss: 0.0209 Acc: 0.8774
# Confusion Meter:
#  [[595  78]
#  [ 78 521]]
# kappa:  0.7538840117382364
#
#
# valid Loss: 0.0267 Acc: 0.8299
# Confusion Meter:
#  [[121  27]
#  [ 22 118]]
# kappa:  0.659787849566056
#
# Epoch     2: reducing learning rate of group 0 to 1.0000e-05.
# Time elapsed: 0m 60s
#
# Epoch 4/10
# ----------
#
# train Loss: 0.0162 Acc: 0.9049
# Confusion Meter:
#  [[633  40]
#  [ 81 518]]
# kappa:  0.8083812654067379
#
#
# valid Loss: 0.0249 Acc: 0.8403
# Confusion Meter:
#  [[127  21]
#  [ 25 115]]
# kappa:  0.6800618238021638
#
# Time elapsed: 1m 20s
#
# Epoch 5/10
# ----------
#
# train Loss: 0.0142 Acc: 0.9198
# Confusion Meter:
#  [[624  49]
#  [ 53 546]]
# kappa:  0.8390189066924082
#
#
# valid Loss: 0.0240 Acc: 0.8646
# Confusion Meter:
#  [[127  21]
#  [ 18 122]]
# kappa:  0.7291144125024118
#
# Epoch     4: reducing learning rate of group 0 to 1.0000e-06.
# Time elapsed: 1m 39s
#
# Epoch 6/10
# ----------
#
# train Loss: 0.0130 Acc: 0.9261
# Confusion Meter:
#  [[624  49]
#  [ 45 554]]
# kappa:  0.851753766040543
#
#
# valid Loss: 0.0238 Acc: 0.8542
# Confusion Meter:
#  [[125  23]
#  [ 19 121]]
# kappa:  0.7083333333333333
#
# Time elapsed: 1m 59s
#
# Epoch 7/10
# ----------
#
# train Loss: 0.0121 Acc: 0.9363
# Confusion Meter:
#  [[635  38]
#  [ 43 556]]
# kappa:  0.8721503342912876
#
#
# valid Loss: 0.0237 Acc: 0.8611
# Confusion Meter:
#  [[125  23]
#  [ 17 123]]
# kappa:  0.722329348245276
#
# Time elapsed: 2m 19s
#
# Epoch 8/10
# ----------
#
# train Loss: 0.0131 Acc: 0.9261
# Confusion Meter:
#  [[625  48]
#  [ 46 553]]
# kappa:  0.8517265582178615
#
#
# valid Loss: 0.0238 Acc: 0.8611
# Confusion Meter:
#  [[126  22]
#  [ 18 122]]
# kappa:  0.7222222222222223
#
# Time elapsed: 2m 39s
#
# Epoch 9/10
# ----------
#
# train Loss: 0.0122 Acc: 0.9340
# Confusion Meter:
#  [[632  41]
#  [ 43 556]]
# kappa:  0.8674516750898765
#
#
# valid Loss: 0.0238 Acc: 0.8715
# Confusion Meter:
#  [[125  23]
#  [ 14 126]]
# kappa:  0.7433031412603586
#
# Epoch     8: reducing learning rate of group 0 to 1.0000e-07.
# Time elapsed: 2m 59s
#
# Epoch 10/10
# ----------
#
# train Loss: 0.0125 Acc: 0.9316
# Confusion Meter:
#  [[625  48]
#  [ 39 560]]
# kappa:  0.8628562930649878
#
#
# valid Loss: 0.0236 Acc: 0.8611
# Confusion Meter:
#  [[124  24]
#  [ 16 124]]
# kappa:  0.7224363916730918
#
# Time elapsed: 3m 19s
#
# Training complete in 3m 19s
# Best valid Acc: 0.871528
# Best valid kappa: 0.743303
#  40%|████      | 14849/36804 [00:00<00:00, 148307.69it/s]
# ----------
#
# XR_ELBOW :
# 100%|██████████| 36804/36804 [00:05<00:00, 6176.44it/s]
# 100%|██████████| 3197/3197 [00:00<00:00, 6681.90it/s]
# Train batches: 309
# Valid batches: 30
#
# Epoch 1/10
# ----------
# train Loss: 0.0314 Acc: 0.7625
# Confusion Meter:
#  [[2541  384]
#  [ 787 1219]]
# kappa:  0.49191979088308474
#
#
# valid Loss: 0.0269 Acc: 0.8258
# Confusion Meter:
#  [[224  11]
#  [ 70 160]]
# kappa:  0.6506191735077222
#
# Time elapsed: 1m 13s
#
# Epoch 2/10
# ----------
#
# train Loss: 0.0265 Acc: 0.8217
# Confusion Meter:
#  [[2639  286]
#  [ 593 1413]]
# kappa:  0.6215523016874143
#
#
# valid Loss: 0.0250 Acc: 0.8258
# Confusion Meter:
#  [[212  23]
#  [ 58 172]]
# kappa:  0.6510076441973593
#
# Time elapsed: 2m 26s
#
# Epoch 3/10
# ----------
#
# train Loss: 0.0247 Acc: 0.8343
# Confusion Meter:
#  [[2671  254]
#  [ 563 1443]]
# kappa:  0.6481895365950378
#
#
# valid Loss: 0.0277 Acc: 0.8301
# Confusion Meter:
#  [[222  13]
#  [ 66 164]]
# kappa:  0.6593406593406593
#
# Time elapsed: 3m 39s
#
# Epoch 4/10
# ----------
#
# train Loss: 0.0226 Acc: 0.8505
# Confusion Meter:
#  [[2689  236]
#  [ 501 1505]]
# kappa:  0.6837552587484821
#
#
# valid Loss: 0.0274 Acc: 0.8473
# Confusion Meter:
#  [[223  12]
#  [ 59 171]]
# kappa:  0.6939229592546238
#
# Epoch     3: reducing learning rate of group 0 to 1.0000e-05.
# Time elapsed: 4m 52s
#
# Epoch 5/10
# ----------
#
# train Loss: 0.0181 Acc: 0.8846
# Confusion Meter:
#  [[2791  134]
#  [ 435 1571]]
# kappa:  0.7551386610494009
#
#
# valid Loss: 0.0272 Acc: 0.8688
# Confusion Meter:
#  [[217  18]
#  [ 43 187]]
# kappa:  0.7373003009956007
#
# Time elapsed: 6m 5s
#
# Epoch 6/10
# ----------
#
# train Loss: 0.0168 Acc: 0.8931
# Confusion Meter:
#  [[2772  153]
#  [ 374 1632]]
# kappa:  0.7746586216910665
#
#
# valid Loss: 0.0225 Acc: 0.8495
# Confusion Meter:
#  [[206  29]
#  [ 41 189]]
# kappa:  0.6987226952980378
#
# Time elapsed: 7m 17s
#
# Epoch 7/10
# ----------
#
# train Loss: 0.0164 Acc: 0.9020
# Confusion Meter:
#  [[2779  146]
#  [ 337 1669]]
# kappa:  0.793965277777177
#
#
# valid Loss: 0.0238 Acc: 0.8559
# Confusion Meter:
#  [[208  27]
#  [ 40 190]]
# kappa:  0.7116212338593975
#
# Time elapsed: 8m 30s
#
# Epoch 8/10
# ----------
#
# train Loss: 0.0145 Acc: 0.9100
# Confusion Meter:
#  [[2797  128]
#  [ 316 1690]]
# kappa:  0.8106467832429595
#
#
# valid Loss: 0.0248 Acc: 0.8366
# Confusion Meter:
#  [[197  38]
#  [ 38 192]]
# kappa:  0.6730804810360778
#
# Epoch     7: reducing learning rate of group 0 to 1.0000e-06.
# Time elapsed: 9m 43s
#
# Epoch 9/10
# ----------
#
# train Loss: 0.0138 Acc: 0.9169
# Confusion Meter:
#  [[2798  127]
#  [ 283 1723]]
# kappa:  0.825590403370125
#
#
# valid Loss: 0.0241 Acc: 0.8409
# Confusion Meter:
#  [[195  40]
#  [ 34 196]]
# kappa:  0.6817719411819106
#
# Time elapsed: 10m 56s
#
# Epoch 10/10
# ----------
#
# train Loss: 0.0133 Acc: 0.9177
# Confusion Meter:
#  [[2800  125]
#  [ 281 1725]]
# kappa:  0.8272919604104165
#
#
# valid Loss: 0.0238 Acc: 0.8559
# Confusion Meter:
#  [[207  28]
#  [ 39 191]]
# kappa:  0.7116479244759129
#
# Epoch     9: reducing learning rate of group 0 to 1.0000e-07.
# Time elapsed: 12m 9s
#
# Training complete in 12m 9s
# Best valid Acc: 0.868817
# Best valid kappa: 0.737300
#  54%|█████▎    | 19778/36804 [00:00<00:00, 196129.06it/s]
# ----------
#
# XR_WRIST :
# 100%|██████████| 36804/36804 [00:13<00:00, 2688.85it/s]
# 100%|██████████| 3197/3197 [00:00<00:00, 4518.29it/s]
# Train batches: 610
# Valid batches: 42
#
# Epoch 1/10
# ----------
#
# train Loss: 0.0285 Acc: 0.7948
# Confusion Meter:
#  [[5049  712]
#  [1288 2699]]
# kappa:  0.5659490889628485
#
#
# valid Loss: 0.0283 Acc: 0.8088
# Confusion Meter:
#  [[318  46]
#  [ 80 215]]
# kappa:  0.6090935625712053
#
# Time elapsed: 2m 23s
#
# Epoch 2/10
# ----------
#
# train Loss: 0.0244 Acc: 0.8364
# Confusion Meter:
#  [[5275  486]
#  [1109 2878]]
# kappa:  0.653200637066276
#
#
# valid Loss: 0.0269 Acc: 0.8164
# Confusion Meter:
#  [[326  38]
#  [ 83 212]]
# kappa:  0.6232595497389619
#
# Time elapsed: 4m 46s
#
# Epoch 3/10
# ----------
#
# train Loss: 0.0229 Acc: 0.8519
# Confusion Meter:
#  [[5315  446]
#  [ 998 2989]]
# kappa:  0.6869120166153287
#
#
# valid Loss: 0.0247 Acc: 0.8498
# Confusion Meter:
#  [[342  22]
#  [ 77 218]]
# kappa:  0.6907496504159456
#
# Time elapsed: 7m 8s
#
# Epoch 4/10
# ----------
#
# train Loss: 0.0214 Acc: 0.8599
# Confusion Meter:
#  [[5331  430]
#  [ 936 3051]]
# kappa:  0.7043605798061614
#
#
# valid Loss: 0.0255 Acc: 0.8452
# Confusion Meter:
#  [[331  33]
#  [ 69 226]]
# kappa:  0.6833462096515857
#
# Time elapsed: 9m 31s
#
# Epoch 5/10
# ----------
#
# train Loss: 0.0203 Acc: 0.8694
# Confusion Meter:
#  [[5366  395]
#  [ 878 3109]]
# kappa:  0.7247376588272423
#
#
# valid Loss: 0.0265 Acc: 0.8392
# Confusion Meter:
#  [[348  16]
#  [ 90 205]]
# kappa:  0.6668129394144637
#
# Epoch     4: reducing learning rate of group 0 to 1.0000e-05.
# Time elapsed: 11m 53s
#
# Epoch 6/10
# ----------
#
# train Loss: 0.0166 Acc: 0.8961
# Confusion Meter:
#  [[5481  280]
#  [ 733 3254]]
# kappa:  0.7812160570765766
#
#
# valid Loss: 0.0261 Acc: 0.8558
# Confusion Meter:
#  [[341  23]
#  [ 72 223]]
# kappa:  0.7038258294343337
#
# Time elapsed: 14m 16s
#
# Epoch 7/10
# ----------
#
# train Loss: 0.0148 Acc: 0.9089
# Confusion Meter:
#  [[5475  286]
#  [ 602 3385]]
# kappa:  0.8092402798471404
#
#
# valid Loss: 0.0287 Acc: 0.8634
# Confusion Meter:
#  [[347  17]
#  [ 73 222]]
# kappa:  0.7187713375312951
#
# Epoch     6: reducing learning rate of group 0 to 1.0000e-06.
# Time elapsed: 16m 39s
#
# Epoch 8/10
# ----------
#
# train Loss: 0.0140 Acc: 0.9125
# Confusion Meter:
#  [[5506  255]
#  [ 598 3389]]
# kappa:  0.8165653394994701
#
#
# valid Loss: 0.0272 Acc: 0.8649
# Confusion Meter:
#  [[349  15]
#  [ 74 221]]
# kappa:  0.7216228659303524
#
# Time elapsed: 19m 1s
#
# Epoch 9/10
# ----------
#
# train Loss: 0.0139 Acc: 0.9135
# Confusion Meter:
#  [[5509  252]
#  [ 591 3396]]
# kappa:  0.8187441785737634
#
#
# valid Loss: 0.0286 Acc: 0.8619
# Confusion Meter:
#  [[350  14]
#  [ 77 218]]
# kappa:  0.7149938454373067
#
# Epoch     8: reducing learning rate of group 0 to 1.0000e-07.
# Time elapsed: 21m 24s
#
# Epoch 10/10
# ----------
#
# train Loss: 0.0134 Acc: 0.9148
# Confusion Meter:
#  [[5497  264]
#  [ 567 3420]]
# kappa:  0.8215756711373474
#
#
# valid Loss: 0.0284 Acc: 0.8619
# Confusion Meter:
#  [[349  15]
#  [ 76 219]]
# kappa:  0.7151806450693656
#
# Time elapsed: 23m 47s
#
# Training complete in 23m 47s
# Best valid Acc: 0.864947
# Best valid kappa: 0.721623
# ----------

# %%
f = open("result.txt",'w')
for item in acc:
    print()
    f.write(item + "accuracy: " + str(acc[item]) + "\n")
    f.write(item + "kappa: " + str(kappa[item]) + "\n")
f.close()
